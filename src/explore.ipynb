# %%
! pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd

# %%
! pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
results = pd.read_csv('../data/raw/results.csv')
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
olympics_data=pd.read_excel('../data/raw/olympics-data.xlsx', sheet_name='results')

# %%
olympics_data
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
ol_data_summer = olympics_data[olympics_data['type']=='Summer']
ol_data_summer
# Out:
#           year    type                      discipline  \
# 0       1912.0  Summer                          Tennis
# 1       1912.0  Summer                          Tennis
# 2       1920.0  Summer                          Tennis
# 3       1920.0  Summer                          Tennis
# 4       1920.0  Summer                          Tennis
# ...        ...     ...                             ...
# 306444  1996.0  Summer           Water Polo (Aquatics)
# 306445  1920.0  Summer                          Rowing
# 307863  2018.0  Summer  Roller Skating (Roller Sports)
# 308325  2018.0  Summer                       Triathlon
# 308326  2018.0  Summer                       Triathlon
#
#                              event                        as  athlete_id  noc  \
# 0           Singles, Men (Olympic)     Jean-François Blanchy           1  FRA
# 1           Doubles, Men (Olympic)     Jean-François Blanchy           1  FRA
# ...

# %%
noc_regions  = pd.read_csv('/workspaces/clase-tlt/data/raw/noc_regions.csv')
noc_regions
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
results_new = pd.merge(ol_data_summer, noc_regions,left_on='noc',right_on='NOC', how ='left')
results_new
# Out:
#           year    type                      discipline  \
# 0       1912.0  Summer                          Tennis
# 1       1912.0  Summer                          Tennis
# 2       1920.0  Summer                          Tennis
# 3       1920.0  Summer                          Tennis
# 4       1920.0  Summer                          Tennis
# ...        ...     ...                             ...
# 241293  1996.0  Summer           Water Polo (Aquatics)
# 241294  1920.0  Summer                          Rowing
# 241295  2018.0  Summer  Roller Skating (Roller Sports)
# 241296  2018.0  Summer                       Triathlon
# 241297  2018.0  Summer                       Triathlon
#
#                              event                        as  athlete_id  noc  \
# 0           Singles, Men (Olympic)     Jean-François Blanchy           1  FRA
# 1           Doubles, Men (Olympic)     Jean-François Blanchy           1  FRA
# ...

# %%
archivo_cruce_1 = '/workspaces/clase-tlt/src/explore.ipynb'
archivo_cruce_2 = '/workspaces/clase-tlt/data/raw/noc_regions.csv'

olympics_data=pd.read_excel(archivo_cruce_1, sheet_name='results')
noc_regions  = pd.read_csv(archivo_cruce_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 4
#       1 archivo_cruce_1 = '/workspaces/clase-tlt/src/explore.ipynb'
#       2 archivo_cruce_2 = '/workspaces/clase-tlt/data/raw/noc_regions.csv'
# ----> 4 olympics_data=pd.read_excel(archivo_cruce_1, sheet_name='results')
#       5 noc_regions  = pd.read_csv(archivo_cruce_2)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...
